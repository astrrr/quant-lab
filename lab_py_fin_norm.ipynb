# %% [markdown]
# <a href="https://colab.research.google.com/github/astrrr/quant-lab/blob/main/lab_py_fin_norm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from util import *

# %%
print(os.getcwd())
# Out:
# /content

# %% [markdown]
# # **Get stocks**

# %%
all_st = pd.read_csv('/content/allstocks.csv')

# %%
all_st.tail()
# Out:
#         Unnamed: 0  Symbol      Date      Open      High       Low     Close  \
# 117435          61     MFC  19920313   18.9000   19.0000   18.8000   18.8000
# 117436          62    MINT  19920313    0.8590    0.8590    0.8455    0.8590
# 117437          63      MK  19920313   12.3385   12.4349   12.0493   12.1457
# 117438          64  MODERN  19920313  102.3490  108.1820  100.7580  108.1820
# 117439          65      NC   1992031       NaN       NaN       NaN       NaN
#
#            Volume
# 117435   310000.0
# 117436   586100.0
# 117437   807619.0
# 117438  3538542.0
# 117439        NaN

# %%
symbols = all_st['Symbol'].unique()

# %%
symbols
# Out:
# array(['SET', 'BAY', 'BBL', 'KBANK', 'SCCC', 'SSC', 'TMB', 'ICC', 'SCB',
#        'SCC', 'SPI', 'UFM', 'BJC', 'TCAP', 'TGCI', 'SPC', 'TF', 'TISCO',
#        'UP', 'WG', 'ICBCT', 'NC', 'CIMBT', 'CTW', 'TCMC', 'TPC', 'SINGER',
#        'BFIT', 'SFP', 'OCC', 'CPF', 'PR', 'DTC', 'PDI', 'POST', 'BBL-F',
#        'KBANK-F', 'SCC-F', 'TCAP-F', 'DTM', 'AYUD', 'DTC-F', 'PDI-F',
#        'SMG', 'THL', 'SCB-F', 'TF-F', 'SKR', 'UT-F', 'BAY-F', 'BRC-F',
#        'SCCC-F', 'ICC-F', 'SSC-F', 'CSC', 'TIC', 'BKI', 'SPI-F', 'SUC-F',
#        'TCMC-F', 'BJC-F', 'SFP-F', 'SGF', 'AFC-F', 'FE', 'TGCI-F',
#        'BKI-F', 'SPC-F', 'BFIT-F', 'CNS', 'IFEC', 'NEP', 'NMG', 'OHTL',
#        'OHTL-F', 'SINGER-F', 'WACOAL-F', 'SCIB', 'ERW', 'KKP', 'KCE',
#        'S&J', 'AYUD-F', 'PAF-F', 'NC-F', 'TNL-F', 'UV', 'SICCO', 'BUI',
#        'HTC', 'CTW-F', 'LH', 'HTC-F', 'POST-F', 'WG-F', 'SNP', 'RCL-F',
#        'UV-F', 'CSC-F', 'BANPU', 'KCE-F', 'TPC-F', 'CPF-F', 'UP-F', 'ROH',
# ...

# %%
st_list = ['KBANK', 'MK', 'CPF', 'TMB', 'STA']
port = pd.DataFrame()

for i in range(len(st_list)):
  st = get_stock(st_list[i], all_st)
  port[i] = st['Close']

# %%
port.columns = st_list
port.head()
# Out:
#               KBANK  MK  CPF      TMB  STA
# Date
# 1984-01-03  13.1407 NaN  NaN  11.4345  NaN
# 1984-01-04  13.1407 NaN  NaN  11.2840  NaN
# 1984-01-05  13.1407 NaN  NaN  11.2840  NaN
# 1984-01-06  12.9321 NaN  NaN  11.2840  NaN
# 1984-01-09  12.9321 NaN  NaN  11.2840  NaN

# %%
port.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2012 entries, 1984-01-03 to 1992-03-13
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   KBANK   2012 non-null   float64
#  1   MK      484 non-null    float64
#  2   CPF     1040 non-null   float64
#  3   TMB     1881 non-null   float64
#  4   STA     135 non-null    float64
# dtypes: float64(5)
# memory usage: 94.3 KB

# %% [markdown]
# # **Missing value**

# %%
port.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
port.dropna(inplace=True)

# %%
port.plot()
plt.show()

# %%
port.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 135 entries, 1991-08-22 to 1992-03-12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   KBANK   135 non-null    float64
#  1   MK      135 non-null    float64
#  2   CPF     135 non-null    float64
#  3   TMB     135 non-null    float64
#  4   STA     135 non-null    float64
# dtypes: float64(5)
# memory usage: 6.3 KB

# %% [markdown]
# # **Normalization**
# (Pt/P0) *100

# %%
port_norm = port/port.iloc[0]

# %%
port_norm.head()
# Out:
#                KBANK        MK       CPF       TMB       STA
# Date
# 1991-08-22  1.000000  1.000000  1.000000  1.000000  1.000000
# 1991-08-23  0.981816  0.961163  0.991884  0.982143  0.909083
# 1991-08-26  0.987877  0.961163  0.991884  1.000000  0.902589
# 1991-08-27  0.981816  0.961163  1.000000  0.982143  0.883107
# 1991-08-28  0.963637  0.941754  1.032527  0.991069  0.837649

# %%
port_norm.plot()
plt.show()
